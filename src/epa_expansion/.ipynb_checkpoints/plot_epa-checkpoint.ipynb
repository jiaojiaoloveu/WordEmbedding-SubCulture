# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
x = np.random.normal(size=100)
sns.distplot(x);
# Out:
# /home/jyuwei/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# %pwd
# Out:
# '/home/jyuwei/code/WordEmbedding-SubCulture/src/semi_supervised'

# %%
from sample_seeds import read_warriner_ratings
csv_path = '../../data/epa/Ratings_Warriner_et_al.csv'
voc = read_warriner_ratings(csv_path)

# %%
e_space = [ for w in vod.keys()]
# Out:
# dict_keys(['originality', 'proposal', 'circumvent', 'educator', 'probing', 'implant', 'canvass', 'poll', 'vertebra', 'regular', 'badge', 'jumpsuit', 'annul', 'diaper', 'disdain', 'patience', 'sodium', 'scare', 'other', 'threat', 'seem', 'keyword', 'mom', 'grievance', 'undefeated', 'grasshopper', 'admiralty', 'parking', 'lyric', 'sizzle', 'camel', 'apologetic', 'prerogative', 'extraordinaire', 'washout', 'decompression', 'mantle', 'railway', 'texture', 'intrude', 'social', 'sentinel', 'overtime', 'brunch', 'quiet', 'landscaping', 'taxicab', 'Coke', 'helmet', 'incomplete', 'chimp', 'backboard', 'civilized', 'sigh', 'diverse', 'ether', 'inspection', 'ingenious', 'retail', 'emphysema', 'weasel', 'regroup', 'quarantine', 'mathematical', 'agony', 'interested', 'poisonous', 'conversational', 'exchange', 'onion', 'snowboard', 'linguini', 'nationality', 'payment', 'paralysis', 'equalizer', 'accounting', 'deduction', 'hurtful', 'decryption', 'pussycat', 'orbit', 'puberty', 'clutter', 'inflatable', 'boar', 'poise', 'induction', 'consummate', 'grief', 'electrocution', 'rhyme', 'element', 'civil', 'envelope', 'inspired', 'hellhole', 'member', 'fucking', 'authenticate', 'confusing', 'coloring', 'flier', 'friendship', 'nimble', 'dropout', 'abduction', 'forgive', 'pro', 'marital', 'command', 'legend', 'volatile', 'auditorium', 'kidnapper', 'bodyguard', 'headphones', 'deprive', 'annihilate', 'intoxicating', 'twit', 'slum', 'aggressiveness', 'gymnast', 'leisurely', 'liaison', 'local', 'gator', 'undersecretary', 'dictatorship', 'mini', 'novelty', 'pubic', 'serve', 'flashy', 'gimmick', 'varsity', 'broken', 'portrait', 'joy', 'fullness', 'bulge', 'nod', 'payback', 'polish', 'settlement', 'crud', 'idle', 'incidental', 'oppose', 'electronic', 'translator', 'hear', 'frosting', 'proper', 'eyeglasses', 'reward', 'cluster', 'mend', 'chalk', 'constant', 'equate', 'wise', 'aquatic', 'shallow', 'ankle', 'hostile', 'wrestling', 'demonstrate', 'browse', 'upholstery', 'macho', 'shipwreck', 'derelict', 'layman', 'penmanship', 'percentile', 'outgoing', 'civilization', 'miscarriage', 'audition', 'chunky', 'pancakes', 'asinine', 'breach', 'hanger', 'fashionable', 'reserve', 'nylon', 'minimal', 'vigorous', 'comb', 'intrusive', 'rob', 'mood', 'translate', 'prognosis', 'solicit', 'grimy', 'decrepit', 'amusing', 'paprika', 'coworker', 'complication', 'span', 'eighteen', 'grandiose', 'vibrator', 'bawl', 'relaxation', 'symbolize', 'excite', 'confiscate', 'builder', 'sherry', 'requisition', 'chip', 'profiler', 'endearing', 'appropriate', 'politics', 'commendable', 'grounding', 'relate', 'remission', 'tension', 'cynicism', 'burn', 'slap', 'oat', 'infallible', 'chiropractor', 'owl', 'imperial', 'distressing', 'peace', 'compassion', 'peas', 'beseech', 'annoy', 'admissible', 'cat', 'mantra', 'distributor', 'compare', 'giver', 'cord', 'prefect', 'bog', 'tent', 'hollow', 'development', 'pronounce', 'resentful', 'respiration', 'appalled', 'monthly', 'raisin', 'premier', 'extravagance', 'filter', 'astonished', 'file', 'shuffle', 'pileup', 'penthouse', 'appear', 'imaginary', 'quarry', 'improvise', 'penitent', 'molten', 'blockade', 'argue', 'carnivorous', 'godforsaken', 'petrol', 'formal', 'circle', 'childbirth', 'contraption', 'grip', 'hummingbird', 'woodland', 'mannequin', 'comparison', 'department', 'stale', 'valet', 'seek', 'database', 'fright', 'gang', 'skirt', 'certifiable', 'illicit', 'impose', 'pretender', 'deposit', 'jour', 'spend', 'curfew', 'adder', 'satisfying', 'maneuver', 'lithium', 'beginning', 'dubious', 'prejudicial', 'soulless', 'godsend', 'dismay', 'fetish', 'unmanned', 'optimum', 'sultan', 'probe', 'pump', 'resignation', 'plate', 'worrying', 'commandment', 'handsome', 'turtle', 'juggler', 'cemetery', 'disclose', 'serenity', 'court', 'guy', 'sadist', 'seriousness', 'humiliating', 'result', 'lint', 'nanometer', 'performer', 'evacuate', 'ninny', 'infuser', 'hairdo', 'unisex', 'malice', 'impersonate', 'extravagant', 'fleet', 'warfare', 'parasol', 'doorbell', 'segm ...
