# %%
import os
import json
os.chdir('..')
# %pwd
# Out:
# '/home/jyuwei/code/WordEmbedding-SubCulture/src'

# %%
basic_sentiment = ['aggressive', 'angry', 'calm', 'careless',
                   'cautious', 'defensive', 'happy', 'nervous',
                   'sorry', 'thanks'
                   ]
with open('../result/state_prediction/svo_senti_github_comment', 'r') as fp:
    senti = json.load(fp)
for w in senti.keys():
    print(w)
    flag = zip(basic_sentiment, senti[w][1])
    flag_sent = [t[0] for t in flag if t[1] == '1']
    senti[w][1] = flag_sent
# Out:
# ['it', 'be', 'right']
# ['seems', 'like', 'it']
# ['i', 'is', 'weird']
# ['fix', 'do', 'only']
# ['it', 'running', 'result']
# ['rubber', 'put', 'own']
# ['i', 'move', 'more']
# ['it', 'understand', 'pain']
# ['i', 'like', 'name']
# ['it', 'keyed', 'better']
# ['i', 'removed', 'it']
# ['someone', 'read', 'code']
# ['companion', 'get', 'rid']
# ['use', 'fold', 'line']
# ['silently', 'return', 'value']
# ['i', 'contributing', 'contributing']
# ['extra', 'is', 'typo']
# ['i', 'move', 'select']
# ['it', 'touching', 'better']
# ['i', 'get', 'noticeable']
# ['i', 'reverted', 'implementation']
# ['line', 'are', 'flipped']
# ['one', 'is', 'new']
# ['chooser', 'verified', 'account']
# ['i', 'be', 'most']
# ['i', 'used', 'unnecessary']
# ['i', 'do', 'it']
# ['i', 'like', 'it']
# ['it', 'using', 'more']
# ['i', 'understood', 'reason']
# ['i', 'make', 'more']
# ['test', 'have', 'sense']
# ['it', 'let', 'easy']
# ['method', 'is', 'clear']
# ['comment', 'is', 'date']
# ['browser', 'listed', 'danish']
# ['it', 'give', 'null']
# ['default', 'be', 'true']
# ['it', 'reduce', 'bulk']
# ['convention', 'allow', 'special']
# ['i', 'keep', 'way']
# ['i', 'give', 'happy']
# ['it', 'unloading', 'matter']
# ['it', 'use', 'local']
# ['type', 'is', 'conference']
# ['it', 'decipher', 'get']
# ['checking', 'be', 'enough']
# ['i', 'existing', 'file']
# ['i', 'change', 'happy']
# ['i', 'wrote', 'asleep']
# ['i', 'changed', 'ed']
# ['i', 'like', 'idea']
# ['i', 'is', 'correct']
# ['please', 'use', 'style']
# ['option', 'do', 'specific']
# ['post', 'check', 'better']
# ['i', 'used', 'future']
# ['i', 'tested', 'code']
# ['i', 'threaded', 'pair']
# ['i', 'mentioned', 'print']
# ['i', 'work', 'sure']
# ['th', 'set', 'able']
# ['option', 'commented', 'configure']
# ['it', 'is', 'distance']
# ['i', 'add', 'precise']
# ['one', 'catch', 'weather']
# ['i', 'exposed', 'window']
# ['model', 'have', 'predict']
# ['source', 'underlying', 'access']
# ['it', 'fail', 'current']
# ['i', 'is', 'right']
# ['it', 'document', 'better']
# ['i', 'make', 'change']
# ['it', 'being', 'n']
# ['it', 'avoid', 'many']
# ['i', 'merge', 'same']
# ['it', 'is', 'list']
# ['all', 'is', 'undefined']
# ['it', 'is', 'block']
# ['i', 'store', 'same']
# ['people', 'do', 'stuff']
# ['i', 'using', 'problem']
# ['it', 'improved', 'new']
# ['i', 'existing', 'possible']
# ['function', 'indented', 'information']
# ['it', 'are', 'easier']
# ['pipe', 'is', 'character']
# ['it', 'be', 'higher']
# ['i', 'like', 'better']
# ['component', 'is', 'idle']
# ['it', 'is', 'row']
# ['kind', 'is', 'part']
# ['increase', 'adjusted', 'kinetic']
# ['file', 'came', 'sure']
# ['attribute', 'mirror', 'general']
# ['i', 'say', 'optimal']
# ['it', 'set', 'false']
# ['it', 'create', 'efficient']
# ['it', 'made', 'past']
# ['might', 'steal', 'button']
# ['it', 'doing', 'worse']
# ['i', 'use', 'one']
# ['i', 'test', 'more']
# ['i', 'do', 'sure']
# ['it', 'referencing', 'idea']
# ['it', 'seems', 'l']
# ['it', 'doing', 'sense']
# ['library', 'cli', 'argument']
# ['event', 'create', 'new']
# ['entry', 'is', 'value']
# ['code', 'benefit', 'nice']
# ['code', 'is', 'error']
# ['i', 'is', 'magic']
# ['it', 'is', 'compatibility']
# ['i', 'be', 'version']
# ['i', 'told', 'other']
# ['it', 'using', 'object']
# ['plan', 'triggered', 'other']
# ['time', 'executed', 'wrong']
# ['i', 'removed', 'constraint']
# ['bad', 'file', 'name']
# ['i', 'specify', 'regular']
# ['style', 'remain', 'constant']
# ['update', 'based', 'single']
# ['i', 'think', 'mak']
# ['i', 'changed', 'spec']
# ['push', 'commits', 'branch']
# ['it', 'being', 'clear']
# ['it', 'defined', 'good']
# ['comment', 'be', 'nice']
# ['it', 'review', 'good']
# ['i', 'want', 'it']
# ['method', 'be', 'null']
# ['mailbox', 'decide', 'responsible']
# ['it', 'hold', 'josh']
# ['pull', 'missing', 'commit']
# ['variable', 'is', 'extern']
# ['file', 'manage', 'path']
# ['uniquely', 'identifies', 'note']
# ['object', 'is', 'ignorant']
# ['i', 'make', 'other']
# ['i', 'merge', 'other']
# ['net', 'added', 'get']
# ['i', 'pull', 'null']
# ['need', 'removed', 'concise']
# ['i', 'pull', 'physical']
# ['us', 'repeat', 'condition']
# ['it', 'are', 'sure']
# ['it', 'open', 'line']
# ['use', 'are', 'confusing']
# ['it', 'work', 'better']
# ['i', 'remove', 'blank']
# ['i', 'hitting', 'limited']
# ['i', 'like', 'generic']
# ['i', 'preview', 'file']
# ['maybe', 'make', 'more']
# ['it', 'executed', 'caller']
# ['i', 'be', 'weird']
# ['me', 'is', 'granular']
# ['it', 'bellow', 'other']
# ['array', 'is', 'choice']
# ['i', 'be', 'sure']
# ['i', 'like', 'format']
# ['i', 'is', 'similar']
# ['it', 'have', 'few']
# ['people', 'are', 'interested']
# ['vector', 'is', 'necessary']
# ['function', 'have', 'full']
# ['i', 'think', 'it']
# ['thanks', 'understand', 'concern']
# ['it', 'be', 'true']
# ['i', 'needed', 'coordinate']
# ['i', 'removed', 'line']
# ['i', 'play', 'safe']
# ['logic', 'is', 'correct']
# ['need', 'applies', 'coding']
# ['i', 'wrap', 'commit']
# ['state', 'set', 'superfluous']
# ['value', 'is', 'idea']
# ['i', 'get', 'next']
# ['method', 'be', 'rename']
# ['lot', 'changed', 'indentation']
# ['it', 'raise', 'bad']
# ['anchor', 'is', 'resource']
# ['it', 'provide', 'goal']
# ['it', 'using', 'full']
# ['i', 'get', 'top']
# ['it', 'protected', 'private']
# ['method', 'accepting', 'likely']
# ['part', 'using', 'script']
# ['it', 'be', 'next']
# ['i', 'regarding', 'few']
# ['scan', 'scan', 'other']
# ['i', 'provide', 'new']
# ['lookup', 'is', 'code']
# ['one', 'looking', 'original']
# ['it', 'writing', 'me']
# ['i', 'weigh', 'more']
# ['i', 'open', 'new']
# ['i', 'am', 'dubious']
# ['site', 'be', 'part']
# ['i', 'know', 'way']
# ['it', 't', 'original']
# ['will', 'open', 'issue']
# ['it', 'converted', 'object']
# ['it', 'make', 'more']
# ['i', 'exist', 'empty']
# ['it', 'break', 'other']
# ['i', 'mean', 'sure']
# ['it', 'return', 'better']
# ['it', 'seems', 'solid']
# ['i', 'changed', 'it']
# ['it', 'check', 'unnecessary']
# ['p', 'read', 'easier']
# ['var', 'is', 'readability']
# ['c', 'is', 'safe']
# ['i', 'code', 'happy']
# ['mr', 'use', 'multiple']
# ['i', 'added', 'it']
# ['concern', 'live', 'public']
# ['it', 'happens', 'bunch']
# ['i', 'moved', 'it']
# ['present', 'seen', 'true']
# ['block', 'extends', 'locator']
# ['i', 'simplified', 'little']
# ['i', 'had', 'placeholder']
# ['constructor', 'done', 'null']
# ['color', 'introducing', 'red']
# ['it', 'cause', 'unexpected']
# ['i', 'confused', 'final']
# ['title', 'have', 'same']
# ['strip', 'is', 'nurse']
# ['i', 'remove', 'call']
# ['let', 'identify', 'name']
# ['it', 'were', 'few']
# ['i', 'are', 'better']
# ['it', 'change', 'annoying']
# ['i', 'adding', 'fan']
# ['response', 'be', 'success']
# ['issue', 'is', 'it']
# ['i', 'solve', 'reported']
# ['it', 'service', 'agnostic']
# ['it', 'complete', 'regular']
# ['consistency', 'is', 'important']
# ['it', 'dialog', 'sense']
# ['i', 'take', 'native']
# ['it', 'be', 'data']
# ['i', 'are', 'relevant']
# ['closure', 'being', 'picky']
# ['it', 'use', 'test']
# ['i', 'written', 'deviate']
# ['i', 'had', 'similar']
# ['packaging', 'be', 'usual']
# ['i', 'agree', 'brad']
# ['i', 'merge', 'ok']
# ['it', 'according', 'available']
# ['person', 'is', 'instance']
# ['approach', 'is', 'cleaner']
# ['k', 'is', 'key']
# ['child', 'override', 'extra']
# ['i', 'test', 'happy']
# ['idea', 'is', 'different']
# ['it', 'replace', 'easy']
# ['it', 'do', 'easiest']
# ['i', 'think', 'sure']
# ['i', 'going', 'sure']
# ['code', 'is', 'part']
# ['way', 'seems', 'evaluation']
# ['it', 'be', 'proxy']
# ['i', 'see', 'other']
# ['i', 'factoring', 'comment']
# ['context', 'needed', 'new']
# ['i', 'set', 'object']
# ['i', 'creates', 'bug']
# ['i', 'absolutely', 'sentiment']
# ['i', 'put', 'it']
# ['textual', 'considered', 'different']
# ['i', 'keep', 'different']
# ['it', 'set', 'other']
# ['i', 'needed', 'respective']
# ['i', 'doing', 'query']
# ['i', 'add', 'reluctant']
# ['i', 'revisit', 'subsequent']
# ['lack', 'caused', 'compiler']
# ['it', 'placed', 'own']
# ['bug', 'be', 'separate']
# ['i', 'fixed', 'it']
# ['it', 'do', 'core']
# ['it', 'use', 'better']
# ['response', 'getting', 'annoying']
# ['john', 'is', 'dependent']
# ['version', 'expects', 'pattern']
# ['it', 'removing', 'me']
# ['it', 'introducing', 'unneeded']
# ['i', 'wrote', 'it']
# ['i', 'do', 'thing']
# ['filter', 'executed', 'spec']
# ['file', 'see', 'automatic']
# ['i', 'is', 'original']
# ['i', 'commented', 'call']
# ['it', 'wrap', 'nice']
# ['it', 'make', 'practice']
# ['method', 'make', 'clear']
# ['it', 'happen', 'likely']
# ['i', 'keeping', 'clean']
# ['state', 'is', 'interesting']
# ['better', 'add', 'license']
# ['let', 'put', 'public']
# ['i', 'live', 'team']
# ['i', 'include', 'public']
# ['i', 'see', 'inconsistency']
# ['i', 'be', 'original']
# ['it', 'do', 'great']
# ['function', 'lost', 'synchronous']
# ['i', 'made', 'change']
# ['i', 'convinced', 'explicit']
# ['i', 'implement', 'code']
# ['i', 'working', 'hesitant']
# ['i', 'agree', 'principal']
# ['i', 'is', 'better']
# ['test', 'test', 'it']
# ['object', 'do', 'more']
# ['method', 'be', 'likely']
# ['us', 'stuck', 'access']
# ['i', 'dare', 'thorough']
# ['name', 'object', 'initialization']
# ['user', 'offset', 'shadow']
# ['it', 'is', 'true']
# ['i', 'wrote', 'post']
# ['use', 'handle', 'remainder']
# ['me', 'is', 'linux']
# ['it', 'following', 'syntax']
# ['i', 'adding', 'global']
# ['i', 'coded', 'similar']
# ['it', 'customized', 'weird']
# ['i', 'avoid', 'comment']
# ['implementation', 'switched', 'common']
# ['i', 'needed', 'pair']
# ['it', 'named', 'default']
# ['it', 'think', 'better']
# ['i', 'getting', 'rid']
# ['i', 'sum', 'whole']
# ['git', 'seems', 'addition']
# ['way', 'removing', 'me']
# ['check', 'is', 'need']
# ['it', 'handle', 'negative']
# ['it', 'work', 'slowdown']
# ['i', 'get', 'rid']
# ['i', 'needed', 'id']
# ['it', 'be', 'argument']
# ['difference', 'run', 'configure']
# ['i', 'using', 'different']
# ['data', 'sent', 'multiple']
# ['it', 'return', 'true']
# ['filter', 'is', 'search']
# ['it', 'isolate', 'better']
# ['i', 'snuff', 'older']
# ['i', 'is', 'enough']
# ['i', 'converted', 'array']
# ['row', 'is', 'index']
# ['it', 'embedded', 'first']
# ['call', 'is', 'call']
# ['i', 'be', 'wrong']
# ['one', 'is', 'tricky']
# ['it', 'threw', 'better']
# ['i', 'introducing', 'explicit']
# ['it', 'is', 'likely']
# ['doc', 'is', 'null']
# ['i', 'having', 'function']
# ['course', 'be', 'desirable']
# ['executor', 'used', 'lexical']
# ['seems', 'like', 'move']
# ['nt', 'sorted', 'false']
# ['it', 'consume', 'additional']
# ['it', 'separate', 'sense']
# ['script', 'used', 'arbitrary']
# ['header', 'is', 'present']
# ['timer', 'seems', 'awful']
# ['i', 'run', 'much']
# ['it', 'occur', 'possible']
# ['debug', 'is', 'true']
# ['reason', 'be', 'consistent']
# ['i', 'work', 'complicated']
# ['i', 'using', 'magic']
# ['i', 'support', 'sure']
# ['i', 'expected', 'hash']
# ['it', 'add', 'good']
# ['vertex', 'coming', 'sharp']
# ['use', 'passed', 'additional']
# ['it', 'is', 'sync']
# ['it', 'reference', 'variable']
# ['it', 'be', 'succinct']
# ['it', 'referred', 'job']
# ['it', 'losing', 'possible']
# ['it', 'use', 'same']
# ['i', 'isolating', 'potential']
# ['i', 'having', 'single']
# ['i', 'recover', 'sure']
# ['nickname', 'is', 'room']
# ['change', 'expect', 'driven']
# ['i', 'did', 'lot']
# ['signal', 'implies', 'semantic']
# ['i', 'is', 'happy']
# ['i', 'filter', 'native']
# ['i', 'found', 'it']
# ['i', 'deleting', 'code']
# ['it', 'considered', 'obfuscated']
# ['i', 'check', 'commit']
# ['it', 'code', 'opinion']
# ['i', 'imagining', 'more']
# ['i', 'did', 'test']
# ['argument', 'is', 'unnecessary']
# ['user', 'modifying', 'one']
# ['it', 'move', 'helpful']
# ['i', 'running', 'it']
# ['i', 'handling', 'particular']
# ['rest', 'is', 'thanks']
# ['security', 'be', 'sufficient']
# ['i', 'added', 'documentation']
# ['it', 'figure', 'me']
# ['it', 'is', 'clear']
# ['i', 'noticed', 'thing']
# ['i', 'convert', 'different']
# ['pid', 'be', 'unlikely']
# ['i', 'dropping', 'live']
# ['use', 'summon', 'dragon']
# ['i', 'use', 'local']
# ['code', 'do', 'nothing']
# ['row', 'be', 'index']
# ['i', 'is', 'initial']
# ['i', 'do', 'nice']
# ['i', 'introduced', 'set']
# ['pattern', 'followed', 'case']
# ['it', 'done', 'develop']
# ['it', 'is', 'internal']
# ['i', 'found', 'useful']
# ['it', 'be', 'necessary']
# ['i', 'merge', 'possible']
# ['it', 'is', 'ambiguous']
# ['time', 'including', 'first']
# ['it', 'be', 'ugly']
# ['it', 'is', 'code']
# ['i', 'use', 'merged']
# ['flag', 'be', 'changeable']
# ['i', 'is', 'clearer']
# ['it', 'include', 'better']
# ['explicit', 'is', 'better']
# ['it', 'catch', 'actual']
# ['leftover', 'were', 'synchronous']
# ['compiler', 'stored', 'tough']
# ['it', 'do', 'style']
# ['i', 'submitted', 'pr']
# ['advice', 'be', 'good']
# ['it', 'happen', 'unlikely']
# ['type', 'is', 'string']
# ['i', 'is', 'sure']
# ['intent', 'is', 'clear']
# ['i', 'clean', 'sure']
# ['output', 'is', 'file']
# ['page', 'be', 'bad']
# ['let', 'change', 'test']
# ['string', 'time', 'same']
# ['service', 'is', 'available']
# ['it', 'twig', 'function']
# ['i', 'found', 'matter']
# ['it', 'redo', 'easier']
# ['sorry', 'is', 'redundant']
# ['it', 'avoid', 'chrome']
# ['it', 'is', 'square']
# ['i', 'have', 'constant']
# ['it', 'is', 'point']
# ['it', 'be', 'merge']
# ['db', 'is', 'specific']
# ['ranking', 'is', 'different']
# ['i', 'be', 'short']
# ['i', 'like', 'whole']
# ['it', 'seemed', 'large']
# ['it', 'do', 'useful']
# ['i', 'keep', 'explicit']
# ['unix', 'command', 'line']
# ['way', 'were', 'least']
# ['it', 'belongs', 'branch']
# ['lambda', 'is', 'win']
# ['original', 'added', 'option']
# ['it', 'figure', 'easier']
# ['it', 'take', 'clear']
# ['i', 'are', 'clearer']
# ['i', 'liked', 'space']
# ['sort', 'is', 'unnecessary']
# ['i', 'describe', 'url']
# ['nitpick', 'known', 'illegible']
# ['brace', 'is', 'end']
# ['i', 'loaded', 'context']
# ['it', 'remove', 'sense']
# ['routing', 'arrives', 'new']
# ['latter', 'be', 'single']
# ['it', 'used', 'me']
# ['input', 'is', 'string']
# ['update', 'worked', 'fine']
# ['method', 'determine', 'useful']
# ['it', 'have', 'feature']
# ['i', 'break', 'sure']
# ['it', 'find', 'specific']
# ['do', 'affect', 'test']
# ['it', 'create', 'started']
# ['i', 'commit', 'local']
# ['line', 'is', 'self']
# ['it', 'is', 'possible']
# ['i', 'adding', 'undocumented']
# ['i', 'missed', 'one']
# ['method', 'set', 'few']
# ['it', 'handle', 'important']
# ['i', 'cleaned', 'many']
# ['i', 'registered', 'sure']
# ['i', 'say', 'same']
# ['i', 'supplied', 'default']
# ['it', 'doing', 'pain']
# ['i', 'log', 'clean']
# ['it', 'worked', 'video']
# ['declaration', 'be', 'compatible']
# ['use', 'considering', 'argument']
# ['it', 'get', 'moment']
# ['equation', 'includes', 'reach']
# ['code', 'correspond', 'arrival']
# ['it', 'associated', 'state']
# ['i', 'have', 'more']
# ['it', 'maintain', 'bit']
# ['it', 'defaulting', 'true']
# ['redefined', 'compile', 'error']
# ['i', 'ran', 'python']
# ['i', 'thrown', 'documentation']
# ['it', 'service', 'specific']
# ['i', 'rewrite', 'sure']
# ['it', 'is', 'uk']
# ['it', 'return', 'object']
# ['method', 'used', 'few']
# ['logic', 'change', 'other']
# ['change', 'be', 'unnecessary']
# ['connection', 'is', 'secure']
# ['tool', 'required', 'undocumented']
# ['it', 'is', 'real']
# ['i', 'getting', 'wrong']
# ['it', 'use', 'nice']
# ['it', 'being', 'class']
# ['dot', 'is', 'typo']
# ['definition', 'discover', 'same']
# ['lot', 'interacted', 'publisher']
# ['line', 'moved', 'other']
# ['transition', 'is', 'legal']
# ['it', 'merge', 'ok']
# ['level', 'is', 'need']
# ['cancan', 'is', 'system']
# ['it', 'be', 'full']
# ['i', 'loop', 'object']
# ['it', 'called', 'good']
# ['it', 'used', 'implicit']
# ['it', 'going', 'me']
# ['i', 'added', 'test']
# ['i', 'mate', 'cool']
# ['i', 'done', 'much']
# ['i', 'merge', 'it']
# ['thing', 'added', 'public']
# ['i', 'comment', 'call']
# ['date', 'be', 'updated']
# ['closing', 'belong', 'line']
# ['i', 'agree', 'magic']
# ['it', 'is', 'first']
# ['i', 'know', 'nothing']
# ['probably', 'cd', 'first']
# ['user', 'be', 'fine']
# ['i', 'emulating', 'it']
# ['i', 'testing', 'same']
# ['user', 'is', 'moderator']
# ['it', 'read', 'possible']
# ['shake', 'name', 'numeric']
# ['it', 'include', 'ok']
# ['change', 'take', 'place']
# ['it', 'load', 'regular']
# ['it', 'obtain', 'way']
# ['goal', 'keep', 'minimal']
# ['i', 'let', 'ok']
# ['message', 'are', 'fine']
# ['explanation', 'is', 'reader']
# ['i', 'took', 'it']
# ['i', 'hammered', 'urgent']
# ['it', 'work', 'easier']
# ['it', 'are', 'external']
# ['case', 'extends', 'class']
# ['i', 'credit', 'sure']
# ['it', 'override', 'possible']
# ['i', 'returning', 'constant']
# ['implementation', 'require', 'browser']
# ['i', 'corrected', 'mistake']
# ['i', 'handle', 'sure']
# ['share', 'function', 'header']
# ['i', 'remove', 'pull']
# ['it', 'made', 'someone']
# ['it', 'be', 'difficult']
# ['method', 'is', 'slower']
# ['i', 'have', 'grammar']
# ['value', 'accept', 'equivalent']
# ['i', 'added', 'new']
# ['it', 'hold', 'easier']
# ['it', 'seems', 'wrong']
# ['reason', 'touching', 'sake']
# ['i', 'am', 'boat']
# ['i', 'making', 'additional']
# ['line', 'is', 'unnecessary']
# ['patch', 'fix', 'it']
# ['comment', 'is', 'useful']
# ['method', 'see', 'unnecessary']
# ['file', 'bring', 'user']
# ['it', 'search', 'hard']
# ['prototype', 'is', 'standard']
# ['renames', 'be', 'good']
# ['it', 'is', 'helpful']
# ['git', 'is', 'crazy']
# ['change', 'change', 'above']
# ['i', 'inherit', 'commit']
# ['i', 'duplicate', 'able']
# ['audio', 'is', 'process']
# ['sense', 'do', 'best']
# ['code', 'ignores', 'draft']
# ['it', 'be', 'more']
# ['i', 'am', 'okay']
# ['sentence', 'be', 'own']
# ['fix', 'is', 'different']
# ['i', 'gather', 'able']
# ['custom', 'tag', 'template']
# ['i', 'using', 'normal']
# ['it', 'move', 'faster']
# ['way', 'preceding', 'blank']
# ['response', 'please', 'use']
# ['it', 'debugging', 'development']
# ['i', 'name', 'variable']
# ['i', 'faced', 'problem']
# ['alright', 'finished', 'review']
# ['i', 'curious', 'apparent']
# ['generator', 'be', 'efficient']
# ['it', 'have', 'best']
# ['i', 'operated', 'code']
# ['i', 'keep', 'dumb']
# ['it', 'override', 'sign']
# ['i', 'blame', 'day']
# ['it', 'made', 'sense']
# ['it', 'create', 'practise']
# ['seems', 'have', 'independent']
# ['it', 'be', 'explicit']
# ['use', 'is', 'useless']
# ['variant', 'is', 'better']
# ['i', 'sticking', 'necessary']
# ['it', 'be', 'recent']
# ['method', 'return', 'builder']
# ['i', 'reproducing', 'interested']
# ['it', 'be', 'place']
# ['it', 'point', 'old']
# ['i', 'is', 'good']
# ['line', 'be', 'indented']
# ['it', 'is', 'issue']
# ['it', 'implement', 'idea']
# ['me', 'ask', 'nicer']
# ['i', 'are', 'sure']
# ['stop', 'stick', 'it']
# ['user', 'selects', 'subject']
# ['i', 'is', 'reliable']
# ['i', 'said', 'ajax']
# ['i', 'keep', 'sure']
# ['it', 'called', 'cleaner']
# ['let', 'leave', 'it']
# ['it', 'follow', 'way']
# ['file', 'made', 'i']
# ['wont', 'need', 'mess']
# ['it', 'gained', 'momentum']
# ['it', 'be', 'clean']
# ['it', 'is', 'place']
# ['i', 'allows', 'sure']
# ['i', 'keep', 'new']
# ['i', 'being', 'check']
# ['it', 'be', 'same']
# ['someone', 'set', 'same']
# ['i', 'got', 'it']
# ['column', 'used', 'original']
# ['bit', 'calculated', 'snow']
# ['it', 'is', 'same']
# ['it', 'is', 'recursive']
# ['it', 'defined', 'same']
# ['customer', 'unpack', 'install']
# ['it', 'added', 'better']
# ['stuff', 'switch', 'comment']
# ['i', 'have', 'answer']
# ['way', 'allow', 'flexibility']
# ['i', 'figured', 'ignores']
# ['it', 'are', 'choice']
# ['i', 'reused', 'variable']
# ['i', 'had', 'higher']
# ['stylistic', 'change', 'free']
# ['i', 'thought', 'it']
# ['it', 'adding', 'time']
# ['i', 'be', 'consistent']
# ['way', 'is', 'fine']
# ['me', 'feel', 'dirty']
# ['i', 'have', 'question']
# ['it', 'match', 'example']
# ['might', 'is', 'different']
# ['year', 'be', 'first']
# ['why', 'is', 'right']
# ['it', 'be', 'equivalent']
# ['i', 'being', 'dense']
# ['typo', 'reassign', 'unit']
# ['i', 'styling', 'latest']
# ['just', 'used', 'it']
# ['me', 'know', 'ok']
# ['resource', 'changed', 'last']
# ['it', 'set', 'kind']
# ['i', 'look', 'good']
# ['i', 'mean', 'code']
# ['it', 'inserted', 'possible']
# ['indentation', 'left', 'untouched']
# ['it', 'used', 'multiple']
# ['i', 'initializing', 'call']
# ['it', 'written', 'worth']
# ['i', 'meant', 'sure']
# ['i', 'do', 'sharing']
# ['it', 'be', 'nice']
# ['priority', 'sharing', 'language']
# ['output', 'appear', 'cleaner']
# ['symbol', 'make', 'trip']
# ['it', 'looking', 'easy']
# ['it', 'ask', 'nicer']
# ['it', 'use', 'ruby']
# ['i', 'did', 'l']
# ['i', 'use', 'source']
# ['filter', 'be', 'confusing']
# ['regardless', 'be', 'consistent']
# ['i', 'impact', 'sure']
# ['let', 'are', 'brief']
# ['i', 'put', 'function']
# ['parenthesis', 'improved', 'purpose']
# ['index', 'have', 'own']
# ['i', 'paste', 'able']
# ['code', 'is', 'clear']
# ['it', 'be', 'wrong']
# ['it', 'be', 'readable']
# ['i', 'interact', 'syntax']
# ['it', 'get', 'wasteful']
# ['i', 'testing', 'many']
# ['message', 'be', 'none']
# ['it', 'match', 'impossible']
# ['i', 'expect', 'quality']
# ['function', 'return', 'old']
# ['line', 'get', 'same']
# ['i', 'fix', 'following']
# ['let', 'keep', 'it']
# ['i', 'getting', 'backwards']
# ['it', 'asking', 'more']
# ['application', 'provide', 'method']
# ['new', 'turn', 'method']
# ['i', 'like', 'thought']
# ['code', 'aggregating', 'sign']
# ['mapping', 'generate', 'first']
# ['i', 'being', 'satisfied']
# ['java', 'is', 'faster']
# ['i', 'let', 'such']
# ['wont', 'need', 'thing']
# ['update', 'are', 'available']
# ['i', 'document', 'proxy']
# ['i', 'find', 'unable']
# ['will', 'say', 'it']
# ['it', 'pushing', 'best']
# ['i', 'do', 'good']
# ['invoke', 'callback', 'function']
# ['i', 'have', 'same']
# ['i', 'do', 'fine']
# ['text', 'is', 'text']
# ['need', 'commented', 'code']
# ['i', 'doing', 'sure']
# ['it', 'were', 'nice']
# ['code', 'is', 'above']
# ['it', 'is', 'adapter']
# ['it', 'be', 'better']
# ['issue', 'is', 'coupling']
# ['i', 'handle', 'fresh']
# ['nested', 'seems', 'code']
# ['it', 'were', 'hack']
# ['i', 'be', 'happy']
# ['i', 'have', 'it']
# ['code', 'enabled', 'more']
# ['it', 'going', 'clear']
# ['me', 'breaking', 'code']
# ['arch', 'know', 'different']
# ['time', 'is', 'necessary']
# ['i', 'get', 'time']
# ['i', 'be', 'better']
# ['i', 'remember', 'specific']
# ['cache', 'have', 'available']
# ['i', 'target', 'able']
# ['it', 'monitor', 'me']
# ['i', 'trying', 'hard']
# ['i', 'insert', 'place']
# ['yeah', 'test', 'sense']
# ['i', 'are', 'able']
# ['break', 'make', 'table']
# ['i', 'save', 'other']
# ['order', 'add', 'next']
# ['community', 'have', 'available']
# ['i', 'described', 'comment']
# ['it', 'use', 'necessary']
# ['it', 'adding', 'fundamental']
# ['i', 'are', 'easy']
# ['i', 'is', 'familiar']
# ['it', 'print', 'original']
# ['it', 'is', 'right']
# ['message', 'is', 'wrong']
# ['bit', 'carried', 'test']
# ['i', 'discovered', 'bug']
# ['i', 'do', 'new']
# ['it', 'design', 'possible']
# ['i', 'understand', 'better']
# ['it', 'change', 'weak']
# ['it', 'be', 'ok']
# ['style', 'is', 'available']
# ['it', 'is', 'only']
# ['code', 'reset', 'internal']
# ['people', 'view', 'latest']
# ['i', 'relate', 'ascii']
# ['i', 'be', 'redundant']
# ['i', 'moved', 'line']
# ['it', 'is', 'example']
# ['i', 'checked', 'repository']
# ['i', 'left', 'change']
# ['problem', 'is', 'space']
# ['it', 'used', 'useful']
# ['row', 'reduce', 'template']
# ['return', 'be', 'generic']
# ['indentation', 'is', 'correct']
# ['java', 'chain', 'future']
# ['play', 'have', 'handy']
# ['i', 'happen', 'sure']
# ['i', 'keep', 'difficult']
# ['line', 'replaced', 'more']
# ['point', 'is', 'performance']
# ['i', 'update', 'kinda']
# ['it', 'reading', 'clear']
# ['i', 'prepare', 'separate']
# ['i', 'providing', 'capable']
# ['i', 'are', 'real']
# ['it', 'throw', 'error']
# ['it', 'indented', 'wrong']
# ['i', 'complicated', 'long']
# ['it', 'activated', 'external']
# ['i', 'be', 'enough']
# ['it', 'be', 'consistent']
# ['test', 'be', 'flawed']
# ['i', 'merged', 'master']
# ['queue', 'kept', 'dry']
# ['limitation', 'applies', 'mr']
# ['i', 'testing', 'inclined']
# ['code', 'is', 'valid']
# ['i', 'expected', 'code']
# ['body', 'is', 'stream']
# ['i', 'control', 'l']
# ['it', 'going', 'good']
# ['helper', 'is', 'present']
# ['code', 'seen', 'open']
# ['will', 'push', 'fix']
# ['it', 'test', 'other']
# ['it', 'installed', 'hard']
# ['webpage', 'execute', 'single']
# ['document', 'is', 'editing']
# ['it', 'display', 'wrong']
# ['i', 'overwrite', 'sure']
# ['it', 'is', 'form']
# ['i', 'tried', 'following']
# ['i', 'keep', 'public']
# ['i', 'named', 'data']
# ['it', 'correct', 'late']
# ['it', 'given', 'further']
# ['it', 'rename', 'better']
# ['i', 'like', 'approach']
# ['us', 'running', 'issue']
# ['language', 'is', 'likely']
# ['i', 'repeat', 'same']
# ['i', 'changed', 'case']
# ['it', 'returning', 'name']
# ['us', 'control', 'executable']
# ['version', 'doing', 'way']
# ['name', 'remember', 'available']
# ['version', 'get', 'url']
# ['search', 'is', 'slow']
# ['it', 'do', 'thing']
# ['i', 'change', 'please']
# ['i', 'is', 'necessary']
# ['i', 'herd', 'u']
# ['i', 'adding', 'worth']
# ['it', 'have', 'nice']
# ['i', 'backing', 'it']
# ['change', 'added', 'line']
# ['set', 'be', 'useful']
# ['i', 'defined', 'function']
# ['value', 'seems', 'like']
# ['i', 'lying', 'old']
# ['it', 'omit', 'clear']
# ['i', 'be', 'rude']
# ['it', 'seems', 'internal']
# ['element', 'is', 'type']
# ['might', 'fix', 'git']
# ['i', 'remove', 'future']
# ['code', 'using', 'strict']
# ['it', 'be', 'aware']
# ['it', 'seemed', 'integrity']
# ['it', 'is', 'level']
# ['blob', 'having', 'different']
# ['it', 'setup', 'whole']
# ['i', 'be', 'different']
# ['it', 'is', 'existing']
# ['i', 'add', 'more']
# ['it', 'used', 'worth']
# ['underscore', 'is', 'noisy']
# ['it', 'form', 'callback']
# ['bug', 'parsing', 'option']
# ['i', 'expect', 'partial']
# ['return', 'is', 'none']
# ['i', 'clean', 'unused']
# ['layout', 'changed', 'initial']
# ['it', 'be', 'interesting']
# ['i', 'remove', 'good']
# ['i', 'search', 'similar']
# ['clause', 'is', 'unnecessary']
# ['it', 'indicates', 'kind']
# ['it', 'give', 'unique']
# ['it', 'processed', 'valid']
# ['goal', 'resolve', 'unnecessary']
# ['name', 'did', 'name']
# ['someone', 'injects', 'browser']
# ['it', 'performs', 'necessary']
# ['i', 'are', 'conclusion']
# ['it', 'being', 'such']
# ['i', 'wanted', 'leverage']
# ['it', 'using', 'indented']
# ['response', 'indicates', 'knowledge']
# ['i', 'like', 'faraday']
# ['tag', 'is', 'part']
# ['i', 'changing', 'fine']
# ['change', 'obtaining', 'consequence']
# ['i', 'remove', 'null']
# ['it', 'returned', 'note']
# ['i', 'is', 'harmless']
# ['i', 'override', 'explicit']
# ['i', 'mean', 'file']
# ['it', 'resulting', 'new']
# ['i', 'formatted', 'better']
# ['i', 'got', 'mixed']
# ['object', 'run', 'available']
# ['i', 'convert', 'lower']
# ['point', 'be', 'valid']
# ['bit', 'be', 'helpful']
# ['google', 'is', 'reachable']
# ['console', 'is', 'undefined']
# ['it', 'rounding', 'point']
# ['set', 'is', 'empty']
# ['option', 'make', 'more']
# ['it', 'done', 'way']
# ['accepting', 'adding', 'harder']
# ['i', 'see', 'new']
# ['i', 'consume', 'generic']
# ['line', 'is', 'long']
# ['i', 'agree', 'principle']
# ['i', 'use', 'syntax']
# ['case', 'documented', 'such']
# ['i', 'run', 'it']
# ['it', 'remove', 'fine']
# ['it', 'make', 'sure']
# ['it', 'need', 'best']
# ['information', 'be', 'available']
# ['it', 'using', 'ability']
# ['temporary', 'be', 'capitalized']

# %%
len(senti.keys())
# Out:
# 976

# %%
count = 0
for w in senti.keys():
    pred = [senti[w][0][i][0] for i in [0, 1, 2, 3, 4]]
    truth = senti[w][1]
    if len(set(pred) & set(truth)) > 0:
        print(w)
        print(pred)
        print(truth)
        print('==========')
        count += 1
# Out:
# ['it', 'be', 'right']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['seems', 'like', 'it']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['fix', 'do', 'only']
# ['sorry', 'cautious', 'thanks', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'running', 'result']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious', 'nervous']
# ==========
# ['it', 'keyed', 'better']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['someone', 'read', 'code']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['aggressive', 'cautious']
# ==========
# ['use', 'fold', 'line']
# ['thanks', 'sorry', 'cautious', 'careless', 'angry']
# ['cautious']
# ==========
# ['i', 'contributing', 'contributing']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['careless', 'sorry']
# ==========
# ['extra', 'is', 'typo']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'thanks']
# ==========
# ['it', 'touching', 'better']
# ['thanks', 'sorry', 'careless', 'happy', 'cautious']
# ['cautious', 'nervous']
# ==========
# ['i', 'get', 'noticeable']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'reverted', 'implementation']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['careless', 'sorry']
# ==========
# ['chooser', 'verified', 'account']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['i', 'be', 'most']
# ['thanks', 'sorry', 'careless', 'happy', 'cautious']
# ['cautious']
# ==========
# ['i', 'used', 'unnecessary']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'do', 'it']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['calm', 'cautious']
# ==========
# ['i', 'like', 'it']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'happy', 'thanks']
# ==========
# ['it', 'using', 'more']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious']
# ==========
# ['i', 'make', 'more']
# ['thanks', 'happy', 'sorry', 'careless', 'calm']
# ['calm']
# ==========
# ['test', 'have', 'sense']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm', 'cautious', 'thanks']
# ==========
# ['method', 'is', 'clear']
# ['thanks', 'sorry', 'calm', 'careless', 'happy']
# ['calm', 'cautious']
# ==========
# ['comment', 'is', 'date']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['browser', 'listed', 'danish']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['default', 'be', 'true']
# ['thanks', 'sorry', 'careless', 'calm', 'happy']
# ['calm', 'thanks']
# ==========
# ['convention', 'allow', 'special']
# ['thanks', 'sorry', 'careless', 'cautious', 'happy']
# ['cautious']
# ==========
# ['i', 'keep', 'way']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['cautious']
# ==========
# ['i', 'give', 'happy']
# ['thanks', 'happy', 'sorry', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['it', 'unloading', 'matter']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious']
# ==========
# ['it', 'use', 'local']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['type', 'is', 'conference']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['cautious', 'nervous']
# ==========
# ['it', 'decipher', 'get']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['i', 'existing', 'file']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious', 'nervous']
# ==========
# ['i', 'change', 'happy']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm']
# ==========
# ['i', 'wrote', 'asleep']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['careless', 'sorry']
# ==========
# ['i', 'like', 'idea']
# ['sorry', 'cautious', 'thanks', 'careless', 'angry']
# ['calm', 'thanks']
# ==========
# ['i', 'is', 'correct']
# ['thanks', 'sorry', 'careless', 'cautious', 'calm']
# ['calm']
# ==========
# ['option', 'do', 'specific']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm']
# ==========
# ['post', 'check', 'better']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['i', 'used', 'future']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm']
# ==========
# ['i', 'tested', 'code']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'threaded', 'pair']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious', 'nervous']
# ==========
# ['i', 'mentioned', 'print']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['cautious']
# ==========
# ['th', 'set', 'able']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['calm', 'cautious']
# ==========
# ['option', 'commented', 'configure']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious']
# ==========
# ['it', 'is', 'distance']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['one', 'catch', 'weather']
# ['cautious', 'nervous', 'sorry', 'angry', 'careless']
# ['cautious']
# ==========
# ['i', 'exposed', 'window']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['careless', 'sorry']
# ==========
# ['model', 'have', 'predict']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['source', 'underlying', 'access']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious']
# ==========
# ['i', 'is', 'right']
# ['sorry', 'cautious', 'careless', 'angry', 'thanks']
# ['aggressive', 'cautious']
# ==========
# ['i', 'make', 'change']
# ['thanks', 'happy', 'sorry', 'calm', 'careless']
# ['calm', 'nervous']
# ==========
# ['it', 'being', 'n']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['calm', 'cautious']
# ==========
# ['it', 'avoid', 'many']
# ['thanks', 'sorry', 'careless', 'cautious', 'happy']
# ['calm', 'cautious']
# ==========
# ['i', 'merge', 'same']
# ['thanks', 'happy', 'sorry', 'calm', 'careless']
# ['calm']
# ==========
# ['it', 'is', 'list']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['cautious', 'defensive']
# ==========
# ['i', 'store', 'same']
# ['thanks', 'happy', 'sorry', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['i', 'using', 'problem']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious']
# ==========
# ['it', 'improved', 'new']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm', 'happy']
# ==========
# ['function', 'indented', 'information']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['it', 'are', 'easier']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['pipe', 'is', 'character']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['i', 'like', 'better']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['kind', 'is', 'part']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious']
# ==========
# ['file', 'came', 'sure']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['attribute', 'mirror', 'general']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['cautious', 'nervous']
# ==========
# ['i', 'say', 'optimal']
# ['thanks', 'sorry', 'careless', 'calm', 'cautious']
# ['calm']
# ==========
# ['it', 'set', 'false']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['it', 'create', 'efficient']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm']
# ==========
# ['it', 'made', 'past']
# ['thanks', 'sorry', 'happy', 'cautious', 'careless']
# ['calm', 'cautious']
# ==========
# ['i', 'test', 'more']
# ['thanks', 'sorry', 'cautious', 'careless', 'angry']
# ['cautious', 'nervous']
# ==========
# ['it', 'referencing', 'idea']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious', 'defensive']
# ==========
# ['it', 'seems', 'l']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'doing', 'sense']
# ['thanks', 'happy', 'sorry', 'careless', 'calm']
# ['calm', 'cautious']
# ==========
# ['entry', 'is', 'value']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['careless', 'sorry']
# ==========
# ['code', 'benefit', 'nice']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'is', 'compatibility']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious']
# ==========
# ['i', 'be', 'version']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'thanks']
# ==========
# ['i', 'specify', 'regular']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm']
# ==========
# ['style', 'remain', 'constant']
# ['sorry', 'careless', 'cautious', 'thanks', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'changed', 'spec']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['comment', 'be', 'nice']
# ['thanks', 'sorry', 'careless', 'cautious', 'happy']
# ['calm', 'cautious']
# ==========
# ['it', 'review', 'good']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'want', 'it']
# ['sorry', 'cautious', 'careless', 'angry', 'thanks']
# ['cautious', 'nervous']
# ==========
# ['method', 'be', 'null']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['mailbox', 'decide', 'responsible']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'thanks']
# ==========
# ['it', 'hold', 'josh']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious', 'nervous']
# ==========
# ['pull', 'missing', 'commit']
# ['sorry', 'cautious', 'angry', 'nervous', 'careless']
# ['cautious', 'nervous']
# ==========
# ['variable', 'is', 'extern']
# ['cautious', 'sorry', 'careless', 'nervous', 'angry']
# ['cautious']
# ==========
# ['file', 'manage', 'path']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['uniquely', 'identifies', 'note']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['object', 'is', 'ignorant']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'make', 'other']
# ['thanks', 'happy', 'sorry', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['i', 'merge', 'other']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'thanks']
# ==========
# ['net', 'added', 'get']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm', 'cautious']
# ==========
# ['i', 'pull', 'null']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['us', 'repeat', 'condition']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious', 'defensive']
# ==========
# ['it', 'are', 'sure']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['it', 'open', 'line']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious']
# ==========
# ['use', 'are', 'confusing']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['aggressive', 'cautious']
# ==========
# ['it', 'work', 'better']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['i', 'preview', 'file']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['maybe', 'make', 'more']
# ['thanks', 'happy', 'sorry', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['me', 'is', 'granular']
# ['thanks', 'sorry', 'calm', 'careless', 'happy']
# ['calm']
# ==========
# ['it', 'bellow', 'other']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['array', 'is', 'choice']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'be', 'sure']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm']
# ==========
# ['i', 'is', 'similar']
# ['thanks', 'sorry', 'careless', 'happy', 'cautious']
# ['cautious']
# ==========
# ['function', 'have', 'full']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm']
# ==========
# ['i', 'think', 'it']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious', 'thanks']
# ==========
# ['thanks', 'understand', 'concern']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'thanks']
# ==========
# ['it', 'be', 'true']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['cautious', 'nervous']
# ==========
# ['logic', 'is', 'correct']
# ['thanks', 'sorry', 'careless', 'cautious', 'calm']
# ['calm']
# ==========
# ['state', 'set', 'superfluous']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['aggressive', 'cautious']
# ==========
# ['value', 'is', 'idea']
# ['cautious', 'sorry', 'nervous', 'angry', 'careless']
# ['aggressive', 'cautious']
# ==========
# ['i', 'get', 'next']
# ['thanks', 'sorry', 'careless', 'cautious', 'happy']
# ['calm', 'cautious']
# ==========
# ['method', 'be', 'rename']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious', 'nervous']
# ==========
# ['lot', 'changed', 'indentation']
# ['thanks', 'sorry', 'careless', 'happy', 'cautious']
# ['calm', 'cautious']
# ==========
# ['it', 'raise', 'bad']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'provide', 'goal']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm', 'cautious']
# ==========
# ['it', 'using', 'full']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm']
# ==========
# ['it', 'protected', 'private']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious']
# ==========
# ['method', 'accepting', 'likely']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['i', 'provide', 'new']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['one', 'looking', 'original']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['i', 'weigh', 'more']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious', 'nervous']
# ==========
# ['i', 'am', 'dubious']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['site', 'be', 'part']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'know', 'way']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['calm', 'cautious', 'sorry']
# ==========
# ['will', 'open', 'issue']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious', 'nervous']
# ==========
# ['it', 'converted', 'object']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious', 'nervous']
# ==========
# ['it', 'make', 'more']
# ['thanks', 'happy', 'sorry', 'careless', 'calm']
# ['calm', 'cautious']
# ==========
# ['i', 'exist', 'empty']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'break', 'other']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['aggressive', 'cautious']
# ==========
# ['it', 'return', 'better']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['it', 'seems', 'solid']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['i', 'changed', 'it']
# ['sorry', 'cautious', 'careless', 'thanks', 'angry']
# ['cautious', 'nervous']
# ==========
# ['it', 'check', 'unnecessary']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['p', 'read', 'easier']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious']
# ==========
# ['c', 'is', 'safe']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious', 'thanks']
# ==========
# ['concern', 'live', 'public']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious', 'nervous']
# ==========
# ['it', 'happens', 'bunch']
# ['thanks', 'sorry', 'cautious', 'careless', 'angry']
# ['aggressive', 'cautious']
# ==========
# ['i', 'simplified', 'little']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['color', 'introducing', 'red']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'cause', 'unexpected']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'confused', 'final']
# ['sorry', 'cautious', 'careless', 'thanks', 'angry']
# ['calm', 'cautious', 'nervous']
# ==========
# ['strip', 'is', 'nurse']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious']
# ==========
# ['i', 'remove', 'call']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['let', 'identify', 'name']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'were', 'few']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['i', 'are', 'better']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['cautious', 'happy']
# ==========
# ['i', 'adding', 'fan']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['aggressive', 'cautious']
# ==========
# ['issue', 'is', 'it']
# ['cautious', 'nervous', 'careless', 'angry', 'defensive']
# ['cautious', 'defensive']
# ==========
# ['it', 'service', 'agnostic']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm']
# ==========
# ['consistency', 'is', 'important']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['it', 'dialog', 'sense']
# ['thanks', 'happy', 'sorry', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['i', 'take', 'native']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'be', 'data']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'are', 'relevant']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['thanks']
# ==========
# ['closure', 'being', 'picky']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['calm', 'cautious']
# ==========
# ['it', 'use', 'test']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'written', 'deviate']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['aggressive', 'cautious', 'defensive']
# ==========
# ['i', 'had', 'similar']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['packaging', 'be', 'usual']
# ['thanks', 'sorry', 'careless', 'happy', 'cautious']
# ['sorry']
# ==========
# ['i', 'agree', 'brad']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['person', 'is', 'instance']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious', 'happy']
# ==========
# ['k', 'is', 'key']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['i', 'test', 'happy']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm', 'cautious', 'nervous']
# ==========
# ['it', 'replace', 'easy']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'think', 'sure']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['sorry']
# ==========
# ['way', 'seems', 'evaluation']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious', 'nervous']
# ==========
# ['context', 'needed', 'new']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['cautious', 'nervous']
# ==========
# ['i', 'set', 'object']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['nervous', 'sorry']
# ==========
# ['i', 'absolutely', 'sentiment']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['thanks']
# ==========
# ['i', 'put', 'it']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious', 'nervous']
# ==========
# ['i', 'keep', 'different']
# ['thanks', 'happy', 'sorry', 'calm', 'careless']
# ['calm']
# ==========
# ['i', 'needed', 'respective']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['i', 'doing', 'query']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'thanks']
# ==========
# ['i', 'add', 'reluctant']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious', 'nervous']
# ==========
# ['lack', 'caused', 'compiler']
# ['nervous', 'cautious', 'angry', 'careless', 'aggressive']
# ['cautious', 'nervous']
# ==========
# ['it', 'placed', 'own']
# ['thanks', 'happy', 'sorry', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['bug', 'be', 'separate']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'fixed', 'it']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'use', 'better']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm']
# ==========
# ['version', 'expects', 'pattern']
# ['sorry', 'cautious', 'careless', 'nervous', 'angry']
# ['cautious', 'nervous']
# ==========
# ['it', 'removing', 'me']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'introducing', 'unneeded']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['i', 'wrote', 'it']
# ['sorry', 'cautious', 'careless', 'nervous', 'angry']
# ['cautious', 'nervous']
# ==========
# ['i', 'do', 'thing']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'commented', 'call']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'wrap', 'nice']
# ['thanks', 'sorry', 'careless', 'cautious', 'happy']
# ['calm', 'cautious']
# ==========
# ['it', 'make', 'practice']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['it', 'happen', 'likely']
# ['thanks', 'sorry', 'careless', 'happy', 'cautious']
# ['cautious', 'nervous']
# ==========
# ['i', 'keeping', 'clean']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['defensive', 'thanks']
# ==========
# ['state', 'is', 'interesting']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['better', 'add', 'license']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['aggressive', 'cautious', 'defensive']
# ==========
# ['let', 'put', 'public']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious']
# ==========
# ['i', 'be', 'original']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm']
# ==========
# ['it', 'do', 'great']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['function', 'lost', 'synchronous']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious']
# ==========
# ['i', 'made', 'change']
# ['thanks', 'happy', 'sorry', 'calm', 'careless']
# ['calm']
# ==========
# ['i', 'convinced', 'explicit']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm', 'cautious']
# ==========
# ['i', 'working', 'hesitant']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['i', 'agree', 'principal']
# ['thanks', 'happy', 'sorry', 'calm', 'careless']
# ['calm']
# ==========
# ['i', 'is', 'better']
# ['thanks', 'sorry', 'careless', 'calm', 'cautious']
# ['calm']
# ==========
# ['test', 'test', 'it']
# ['sorry', 'cautious', 'careless', 'nervous', 'angry']
# ['cautious', 'defensive']
# ==========
# ['object', 'do', 'more']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious']
# ==========
# ['method', 'be', 'likely']
# ['thanks', 'sorry', 'calm', 'careless', 'cautious']
# ['cautious', 'nervous']
# ==========
# ['us', 'stuck', 'access']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious']
# ==========
# ['i', 'dare', 'thorough']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious', 'nervous']
# ==========
# ['user', 'offset', 'shadow']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious', 'nervous']
# ==========
# ['it', 'is', 'true']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious', 'nervous']
# ==========
# ['use', 'handle', 'remainder']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious', 'nervous']
# ==========
# ['it', 'following', 'syntax']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['i', 'coded', 'similar']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious', 'nervous']
# ==========
# ['i', 'avoid', 'comment']
# ['sorry', 'cautious', 'angry', 'careless', 'nervous']
# ['calm', 'cautious']
# ==========
# ['i', 'needed', 'pair']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'thanks']
# ==========
# ['it', 'think', 'better']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['way', 'removing', 'me']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['check', 'is', 'need']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['aggressive', 'cautious']
# ==========
# ['it', 'work', 'slowdown']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious', 'nervous']
# ==========
# ['i', 'get', 'rid']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious', 'defensive']
# ==========
# ['i', 'needed', 'id']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'be', 'argument']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['difference', 'run', 'configure']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['calm', 'cautious']
# ==========
# ['it', 'return', 'true']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['cautious', 'nervous']
# ==========
# ['it', 'isolate', 'better']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['i', 'snuff', 'older']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['sorry', 'thanks']
# ==========
# ['i', 'be', 'wrong']
# ['thanks', 'sorry', 'careless', 'happy', 'cautious']
# ['cautious', 'nervous']
# ==========
# ['one', 'is', 'tricky']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['it', 'threw', 'better']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['i', 'introducing', 'explicit']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm']
# ==========
# ['it', 'is', 'likely']
# ['thanks', 'sorry', 'careless', 'cautious', 'calm']
# ['calm', 'cautious']
# ==========
# ['i', 'having', 'function']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious', 'nervous']
# ==========
# ['course', 'be', 'desirable']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['nt', 'sorted', 'false']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['cautious', 'nervous']
# ==========
# ['script', 'used', 'arbitrary']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm', 'cautious']
# ==========
# ['i', 'run', 'much']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['angry', 'cautious', 'defensive']
# ==========
# ['it', 'occur', 'possible']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['debug', 'is', 'true']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['calm', 'cautious']
# ==========
# ['i', 'using', 'magic']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious']
# ==========
# ['i', 'expected', 'hash']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['careless', 'sorry']
# ==========
# ['it', 'add', 'good']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['use', 'passed', 'additional']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'is', 'sync']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['it', 'be', 'succinct']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm']
# ==========
# ['it', 'referred', 'job']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['aggressive', 'cautious']
# ==========
# ['it', 'losing', 'possible']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm', 'happy']
# ==========
# ['it', 'use', 'same']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['i', 'isolating', 'potential']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious']
# ==========
# ['i', 'having', 'single']
# ['thanks', 'sorry', 'careless', 'cautious', 'happy']
# ['cautious']
# ==========
# ['i', 'recover', 'sure']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm']
# ==========
# ['i', 'did', 'lot']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['calm', 'nervous']
# ==========
# ['i', 'is', 'happy']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'happy']
# ==========
# ['i', 'deleting', 'code']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['careless', 'sorry']
# ==========
# ['it', 'code', 'opinion']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious', 'defensive']
# ==========
# ['i', 'imagining', 'more']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'did', 'test']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['calm', 'cautious']
# ==========
# ['argument', 'is', 'unnecessary']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious', 'nervous']
# ==========
# ['it', 'move', 'helpful']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'running', 'it']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['security', 'be', 'sufficient']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious', 'nervous']
# ==========
# ['it', 'figure', 'me']
# ['thanks', 'sorry', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'noticed', 'thing']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious', 'nervous']
# ==========
# ['i', 'convert', 'different']
# ['thanks', 'happy', 'sorry', 'calm', 'careless']
# ['calm']
# ==========
# ['pid', 'be', 'unlikely']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm']
# ==========
# ['use', 'summon', 'dragon']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['cautious', 'nervous']
# ==========
# ['i', 'is', 'initial']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'done', 'develop']
# ['thanks', 'happy', 'sorry', 'careless', 'calm']
# ['nervous', 'sorry']
# ==========
# ['it', 'is', 'internal']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'found', 'useful']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'be', 'necessary']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['it', 'is', 'ambiguous']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm', 'thanks']
# ==========
# ['time', 'including', 'first']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious']
# ==========
# ['it', 'is', 'code']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious', 'nervous']
# ==========
# ['flag', 'be', 'changeable']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['i', 'is', 'clearer']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm', 'cautious']
# ==========
# ['it', 'include', 'better']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm', 'cautious']
# ==========
# ['it', 'catch', 'actual']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['compiler', 'stored', 'tough']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious', 'nervous']
# ==========
# ['it', 'do', 'style']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['advice', 'be', 'good']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious', 'nervous']
# ==========
# ['it', 'happen', 'unlikely']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['intent', 'is', 'clear']
# ['thanks', 'sorry', 'calm', 'happy', 'careless']
# ['calm']
# ==========
# ['output', 'is', 'file']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['page', 'be', 'bad']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['let', 'change', 'test']
# ['cautious', 'nervous', 'sorry', 'angry', 'careless']
# ['calm', 'cautious']
# ==========
# ['service', 'is', 'available']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['it', 'twig', 'function']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious']
# ==========
# ['i', 'found', 'matter']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious']
# ==========
# ['it', 'redo', 'easier']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['sorry', 'is', 'redundant']
# ['thanks', 'sorry', 'careless', 'cautious', 'happy']
# ['sorry']
# ==========
# ['it', 'is', 'square']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['ranking', 'is', 'different']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm']
# ==========
# ['it', 'do', 'useful']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'keep', 'explicit']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['way', 'were', 'least']
# ['cautious', 'sorry', 'angry', 'careless', 'nervous']
# ['cautious', 'sorry']
# ==========
# ['it', 'belongs', 'branch']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious']
# ==========
# ['original', 'added', 'option']
# ['thanks', 'sorry', 'cautious', 'careless', 'angry']
# ['cautious']
# ==========
# ['sort', 'is', 'unnecessary']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious']
# ==========
# ['i', 'describe', 'url']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['nitpick', 'known', 'illegible']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['aggressive', 'cautious']
# ==========
# ['brace', 'is', 'end']
# ['sorry', 'cautious', 'thanks', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'remove', 'sense']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious']
# ==========
# ['latter', 'be', 'single']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'used', 'me']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious']
# ==========
# ['input', 'is', 'string']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['update', 'worked', 'fine']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['cautious']
# ==========
# ['method', 'determine', 'useful']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm']
# ==========
# ['i', 'break', 'sure']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious', 'nervous']
# ==========
# ['do', 'affect', 'test']
# ['sorry', 'cautious', 'careless', 'angry', 'thanks']
# ['cautious']
# ==========
# ['it', 'create', 'started']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious', 'nervous']
# ==========
# ['i', 'commit', 'local']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['nervous', 'sorry']
# ==========
# ['it', 'is', 'possible']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm', 'cautious']
# ==========
# ['i', 'missed', 'one']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['careless', 'thanks']
# ==========
# ['method', 'set', 'few']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious']
# ==========
# ['i', 'log', 'clean']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['declaration', 'be', 'compatible']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious', 'nervous']
# ==========
# ['use', 'considering', 'argument']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['calm', 'cautious']
# ==========
# ['it', 'get', 'moment']
# ['thanks', 'sorry', 'careless', 'happy', 'cautious']
# ['calm', 'cautious']
# ==========
# ['equation', 'includes', 'reach']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['code', 'correspond', 'arrival']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['it', 'associated', 'state']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['i', 'have', 'more']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious']
# ==========
# ['it', 'maintain', 'bit']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['it', 'defaulting', 'true']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['aggressive', 'cautious']
# ==========
# ['redefined', 'compile', 'error']
# ['sorry', 'cautious', 'careless', 'nervous', 'angry']
# ['cautious']
# ==========
# ['i', 'ran', 'python']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['i', 'thrown', 'documentation']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['calm', 'cautious']
# ==========
# ['it', 'service', 'specific']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['sorry']
# ==========
# ['it', 'is', 'uk']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'return', 'object']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious']
# ==========
# ['method', 'used', 'few']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['connection', 'is', 'secure']
# ['sorry', 'thanks', 'careless', 'cautious', 'calm']
# ['aggressive', 'cautious']
# ==========
# ['tool', 'required', 'undocumented']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['aggressive', 'cautious']
# ==========
# ['i', 'getting', 'wrong']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious', 'nervous']
# ==========
# ['it', 'use', 'nice']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['it', 'being', 'class']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious', 'defensive']
# ==========
# ['dot', 'is', 'typo']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['line', 'moved', 'other']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'merge', 'ok']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious', 'nervous']
# ==========
# ['level', 'is', 'need']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'called', 'good']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'used', 'implicit']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['it', 'going', 'me']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['i', 'added', 'test']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious', 'nervous']
# ==========
# ['i', 'done', 'much']
# ['thanks', 'sorry', 'cautious', 'careless', 'angry']
# ['cautious', 'nervous', 'thanks']
# ==========
# ['thing', 'added', 'public']
# ['thanks', 'happy', 'sorry', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['i', 'comment', 'call']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious', 'nervous']
# ==========
# ['closing', 'belong', 'line']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['it', 'is', 'first']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'know', 'nothing']
# ['sorry', 'cautious', 'careless', 'angry', 'thanks']
# ['cautious']
# ==========
# ['probably', 'cd', 'first']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'testing', 'same']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious', 'nervous']
# ==========
# ['user', 'is', 'moderator']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'read', 'possible']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm']
# ==========
# ['it', 'include', 'ok']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['change', 'take', 'place']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['calm', 'cautious', 'nervous']
# ==========
# ['goal', 'keep', 'minimal']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['cautious', 'nervous']
# ==========
# ['i', 'let', 'ok']
# ['cautious', 'sorry', 'careless', 'nervous', 'angry']
# ['calm', 'cautious']
# ==========
# ['message', 'are', 'fine']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['cautious', 'nervous']
# ==========
# ['explanation', 'is', 'reader']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['aggressive', 'cautious', 'defensive']
# ==========
# ['i', 'took', 'it']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['aggressive', 'cautious', 'defensive']
# ==========
# ['i', 'credit', 'sure']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'happy', 'thanks']
# ==========
# ['i', 'returning', 'constant']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['implementation', 'require', 'browser']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['i', 'remove', 'pull']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['cautious', 'nervous']
# ==========
# ['it', 'made', 'someone']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['sorry']
# ==========
# ['method', 'is', 'slower']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['aggressive', 'defensive', 'nervous']
# ==========
# ['i', 'have', 'grammar']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['careless']
# ==========
# ['value', 'accept', 'equivalent']
# ['thanks', 'happy', 'sorry', 'calm', 'careless']
# ['calm']
# ==========
# ['i', 'added', 'new']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm', 'cautious']
# ==========
# ['it', 'seems', 'wrong']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['aggressive', 'cautious']
# ==========
# ['i', 'am', 'boat']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['aggressive', 'cautious']
# ==========
# ['line', 'is', 'unnecessary']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['aggressive', 'cautious']
# ==========
# ['patch', 'fix', 'it']
# ['sorry', 'cautious', 'careless', 'nervous', 'angry']
# ['calm', 'cautious']
# ==========
# ['file', 'bring', 'user']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious', 'nervous']
# ==========
# ['it', 'search', 'hard']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious']
# ==========
# ['prototype', 'is', 'standard']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['renames', 'be', 'good']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious', 'nervous']
# ==========
# ['it', 'is', 'helpful']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'inherit', 'commit']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious']
# ==========
# ['i', 'am', 'okay']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious', 'nervous']
# ==========
# ['sentence', 'be', 'own']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['i', 'gather', 'able']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['cautious', 'nervous']
# ==========
# ['it', 'move', 'faster']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious', 'nervous']
# ==========
# ['it', 'debugging', 'development']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious']
# ==========
# ['alright', 'finished', 'review']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious', 'happy']
# ==========
# ['i', 'curious', 'apparent']
# ['thanks', 'sorry', 'careless', 'cautious', 'calm']
# ['calm', 'thanks']
# ==========
# ['generator', 'be', 'efficient']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm']
# ==========
# ['it', 'have', 'best']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'override', 'sign']
# ['thanks', 'happy', 'sorry', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['i', 'blame', 'day']
# ['cautious', 'nervous', 'angry', 'careless', 'sorry']
# ['sorry']
# ==========
# ['it', 'made', 'sense']
# ['thanks', 'happy', 'sorry', 'calm', 'careless']
# ['calm']
# ==========
# ['it', 'create', 'practise']
# ['thanks', 'sorry', 'careless', 'cautious', 'happy']
# ['calm', 'cautious']
# ==========
# ['seems', 'have', 'independent']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm']
# ==========
# ['it', 'be', 'explicit']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['variant', 'is', 'better']
# ['thanks', 'sorry', 'careless', 'cautious', 'calm']
# ['cautious']
# ==========
# ['method', 'return', 'builder']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['i', 'reproducing', 'interested']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm']
# ==========
# ['it', 'be', 'place']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'point', 'old']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious', 'nervous']
# ==========
# ['i', 'is', 'good']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['line', 'be', 'indented']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm']
# ==========
# ['it', 'is', 'issue']
# ['sorry', 'cautious', 'thanks', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['user', 'selects', 'subject']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm']
# ==========
# ['i', 'is', 'reliable']
# ['sorry', 'thanks', 'careless', 'cautious', 'calm']
# ['cautious']
# ==========
# ['i', 'keep', 'sure']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['let', 'leave', 'it']
# ['sorry', 'cautious', 'nervous', 'careless', 'angry']
# ['cautious', 'nervous']
# ==========
# ['it', 'follow', 'way']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious']
# ==========
# ['file', 'made', 'i']
# ['thanks', 'sorry', 'happy', 'cautious', 'careless']
# ['cautious']
# ==========
# ['it', 'be', 'clean']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['it', 'is', 'place']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['careless']
# ==========
# ['i', 'keep', 'new']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm', 'cautious']
# ==========
# ['i', 'being', 'check']
# ['sorry', 'cautious', 'thanks', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'be', 'same']
# ['thanks', 'happy', 'sorry', 'calm', 'careless']
# ['calm']
# ==========
# ['it', 'is', 'same']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['it', 'defined', 'same']
# ['thanks', 'happy', 'sorry', 'calm', 'careless']
# ['calm']
# ==========
# ['customer', 'unpack', 'install']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['i', 'have', 'answer']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['way', 'allow', 'flexibility']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['aggressive', 'calm']
# ==========
# ['i', 'figured', 'ignores']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'reused', 'variable']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['careless', 'sorry', 'thanks']
# ==========
# ['i', 'had', 'higher']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious', 'nervous']
# ==========
# ['i', 'thought', 'it']
# ['sorry', 'cautious', 'careless', 'angry', 'thanks']
# ['calm', 'cautious']
# ==========
# ['it', 'adding', 'time']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'be', 'consistent']
# ['thanks', 'happy', 'sorry', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['way', 'is', 'fine']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['me', 'feel', 'dirty']
# ['sorry', 'careless', 'cautious', 'angry', 'calm']
# ['calm', 'thanks']
# ==========
# ['i', 'have', 'question']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['it', 'match', 'example']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious', 'thanks']
# ==========
# ['might', 'is', 'different']
# ['thanks', 'sorry', 'careless', 'happy', 'cautious']
# ['calm', 'cautious']
# ==========
# ['year', 'be', 'first']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['it', 'be', 'equivalent']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm', 'cautious']
# ==========
# ['i', 'being', 'dense']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious', 'nervous']
# ==========
# ['typo', 'reassign', 'unit']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'styling', 'latest']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['me', 'know', 'ok']
# ['sorry', 'careless', 'cautious', 'angry', 'thanks']
# ['cautious', 'defensive']
# ==========
# ['resource', 'changed', 'last']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['cautious', 'nervous']
# ==========
# ['it', 'set', 'kind']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious']
# ==========
# ['it', 'used', 'multiple']
# ...
# ['index', 'have', 'own']
# ['thanks', 'sorry', 'careless', 'cautious', 'calm']
# ['calm', 'cautious']
# ==========
# ['code', 'is', 'clear']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['careless', 'sorry', 'thanks']
# ==========
# ['it', 'be', 'readable']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['it', 'get', 'wasteful']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious']
# ==========
# ['i', 'testing', 'many']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['happy', 'thanks']
# ==========
# ['message', 'be', 'none']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['line', 'get', 'same']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['i', 'fix', 'following']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious', 'nervous']
# ==========
# ['i', 'getting', 'backwards']
# ['thanks', 'happy', 'sorry', 'calm', 'careless']
# ['careless', 'nervous', 'thanks']
# ==========
# ['application', 'provide', 'method']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm']
# ==========
# ['i', 'like', 'thought']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['happy', 'thanks']
# ==========
# ['i', 'being', 'satisfied']
# ['thanks', 'sorry', 'careless', 'calm', 'cautious']
# ['aggressive', 'cautious']
# ==========
# ['java', 'is', 'faster']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['angry', 'cautious', 'defensive']
# ==========
# ['i', 'let', 'such']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['update', 'are', 'available']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['i', 'document', 'proxy']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious', 'defensive']
# ==========
# ['i', 'find', 'unable']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['it', 'pushing', 'best']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['i', 'do', 'good']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['invoke', 'callback', 'function']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['cautious', 'nervous']
# ==========
# ['need', 'commented', 'code']
# ['cautious', 'nervous', 'angry', 'careless', 'sorry']
# ['calm', 'cautious']
# ==========
# ['it', 'were', 'nice']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['it', 'is', 'adapter']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'be', 'better']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['issue', 'is', 'coupling']
# ['sorry', 'cautious', 'careless', 'thanks', 'angry']
# ['cautious', 'nervous']
# ==========
# ['i', 'handle', 'fresh']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious', 'nervous']
# ==========
# ['it', 'were', 'hack']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'happy', 'thanks']
# ==========
# ['i', 'be', 'happy']
# ['thanks', 'happy', 'sorry', 'calm', 'careless']
# ['calm', 'happy']
# ==========
# ['code', 'enabled', 'more']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['time', 'is', 'necessary']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'get', 'time']
# ['sorry', 'cautious', 'nervous', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'be', 'better']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['cautious', 'happy', 'thanks']
# ==========
# ['i', 'remember', 'specific']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['cache', 'have', 'available']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm']
# ==========
# ['i', 'target', 'able']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious']
# ==========
# ['it', 'monitor', 'me']
# ['thanks', 'sorry', 'careless', 'cautious', 'happy']
# ['cautious']
# ==========
# ['i', 'trying', 'hard']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious', 'nervous']
# ==========
# ['i', 'insert', 'place']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['nervous', 'sorry']
# ==========
# ['yeah', 'test', 'sense']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'thanks']
# ==========
# ['i', 'are', 'able']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious', 'nervous']
# ==========
# ['i', 'save', 'other']
# ['thanks', 'sorry', 'careless', 'happy', 'cautious']
# ['calm', 'cautious']
# ==========
# ['community', 'have', 'available']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'defensive']
# ==========
# ['it', 'adding', 'fundamental']
# ['thanks', 'happy', 'sorry', 'calm', 'careless']
# ['calm']
# ==========
# ['i', 'is', 'familiar']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['it', 'print', 'original']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['i', 'discovered', 'bug']
# ['sorry', 'cautious', 'careless', 'angry', 'thanks']
# ['aggressive', 'cautious', 'nervous']
# ==========
# ['i', 'understand', 'better']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['careless', 'sorry']
# ==========
# ['it', 'change', 'weak']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'be', 'ok']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious', 'nervous']
# ==========
# ['it', 'is', 'only']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious', 'defensive']
# ==========
# ['code', 'reset', 'internal']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'be', 'redundant']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['it', 'is', 'example']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious', 'happy']
# ==========
# ['problem', 'is', 'space']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['defensive', 'nervous']
# ==========
# ['it', 'used', 'useful']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm']
# ==========
# ['row', 'reduce', 'template']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['cautious', 'nervous']
# ==========
# ['return', 'be', 'generic']
# ['thanks', 'sorry', 'calm', 'careless', 'happy']
# ['calm']
# ==========
# ['play', 'have', 'handy']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'keep', 'difficult']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['cautious', 'nervous', 'sorry']
# ==========
# ['point', 'is', 'performance']
# ['cautious', 'sorry', 'nervous', 'angry', 'careless']
# ['aggressive', 'defensive', 'nervous']
# ==========
# ['i', 'prepare', 'separate']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'sorry']
# ==========
# ['it', 'throw', 'error']
# ['thanks', 'sorry', 'cautious', 'careless', 'angry']
# ['cautious', 'happy', 'thanks']
# ==========
# ['it', 'indented', 'wrong']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious']
# ==========
# ['i', 'complicated', 'long']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious', 'nervous']
# ==========
# ['it', 'activated', 'external']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'be', 'enough']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['it', 'be', 'consistent']
# ['thanks', 'happy', 'sorry', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['test', 'be', 'flawed']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'thanks']
# ==========
# ['queue', 'kept', 'dry']
# ['thanks', 'sorry', 'cautious', 'careless', 'angry']
# ['calm', 'cautious', 'thanks']
# ==========
# ['code', 'is', 'valid']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm']
# ==========
# ['i', 'expected', 'code']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious', 'thanks']
# ==========
# ['body', 'is', 'stream']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['aggressive', 'cautious']
# ==========
# ['i', 'control', 'l']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'going', 'good']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['cautious', 'defensive']
# ==========
# ['helper', 'is', 'present']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm', 'cautious']
# ==========
# ['will', 'push', 'fix']
# ['thanks', 'sorry', 'careless', 'calm', 'cautious']
# ['thanks']
# ==========
# ['it', 'test', 'other']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['aggressive', 'cautious']
# ==========
# ['it', 'installed', 'hard']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm', 'cautious']
# ==========
# ['document', 'is', 'editing']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'display', 'wrong']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious']
# ==========
# ['i', 'overwrite', 'sure']
# ['thanks', 'sorry', 'careless', 'happy', 'calm']
# ['calm']
# ==========
# ['it', 'is', 'form']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['i', 'tried', 'following']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'given', 'further']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['aggressive', 'cautious']
# ==========
# ['it', 'rename', 'better']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['us', 'running', 'issue']
# ['sorry', 'cautious', 'careless', 'nervous', 'angry']
# ['calm', 'cautious', 'nervous']
# ==========
# ['i', 'repeat', 'same']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm']
# ==========
# ['i', 'changed', 'case']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious']
# ==========
# ['it', 'returning', 'name']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious']
# ==========
# ['name', 'remember', 'available']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['version', 'get', 'url']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['search', 'is', 'slow']
# ['cautious', 'nervous', 'angry', 'careless', 'defensive']
# ['aggressive', 'cautious']
# ==========
# ['it', 'do', 'thing']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious', 'nervous']
# ==========
# ['i', 'change', 'please']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['aggressive', 'angry', 'defensive']
# ==========
# ['i', 'adding', 'worth']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['i', 'backing', 'it']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'defined', 'function']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious']
# ==========
# ['it', 'omit', 'clear']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['i', 'be', 'rude']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious', 'defensive', 'sorry']
# ==========
# ['it', 'seems', 'internal']
# ['thanks', 'sorry', 'careless', 'cautious', 'happy']
# ['calm', 'cautious']
# ==========
# ['code', 'using', 'strict']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm']
# ==========
# ['it', 'seemed', 'integrity']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious']
# ==========
# ['it', 'is', 'level']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['blob', 'having', 'different']
# ['thanks', 'happy', 'sorry', 'calm', 'careless']
# ['calm']
# ==========
# ['it', 'used', 'worth']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['underscore', 'is', 'noisy']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious', 'defensive']
# ==========
# ['bug', 'parsing', 'option']
# ['sorry', 'cautious', 'nervous', 'careless', 'angry']
# ['cautious', 'thanks']
# ==========
# ['i', 'expect', 'partial']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['i', 'clean', 'unused']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['sorry']
# ==========
# ['it', 'be', 'interesting']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm']
# ==========
# ['i', 'remove', 'good']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'search', 'similar']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm', 'cautious', 'thanks']
# ==========
# ['clause', 'is', 'unnecessary']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['aggressive', 'cautious']
# ==========
# ['it', 'indicates', 'kind']
# ['thanks', 'sorry', 'careless', 'cautious', 'calm']
# ['aggressive', 'cautious']
# ==========
# ['it', 'give', 'unique']
# ['thanks', 'happy', 'sorry', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['goal', 'resolve', 'unnecessary']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['calm', 'cautious']
# ==========
# ['name', 'did', 'name']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['cautious']
# ==========
# ['someone', 'injects', 'browser']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['aggressive', 'cautious', 'defensive']
# ==========
# ['it', 'performs', 'necessary']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['it', 'being', 'such']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['i', 'wanted', 'leverage']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm']
# ==========
# ['it', 'using', 'indented']
# ['thanks', 'happy', 'sorry', 'calm', 'careless']
# ['calm', 'defensive']
# ==========
# ['response', 'indicates', 'knowledge']
# ['sorry', 'cautious', 'careless', 'angry', 'thanks']
# ['aggressive', 'cautious']
# ==========
# ['i', 'like', 'faraday']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm']
# ==========
# ['i', 'changing', 'fine']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['sorry']
# ==========
# ['i', 'override', 'explicit']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm']
# ==========
# ['i', 'mean', 'file']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['cautious', 'defensive']
# ==========
# ['it', 'resulting', 'new']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['cautious']
# ==========
# ['i', 'formatted', 'better']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['i', 'convert', 'lower']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm']
# ==========
# ['google', 'is', 'reachable']
# ['sorry', 'careless', 'cautious', 'angry', 'thanks']
# ['calm', 'cautious']
# ==========
# ['console', 'is', 'undefined']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['set', 'is', 'empty']
# ['sorry', 'cautious', 'careless', 'angry', 'nervous']
# ['calm', 'cautious']
# ==========
# ['option', 'make', 'more']
# ['thanks', 'happy', 'sorry', 'careless', 'cautious']
# ['calm', 'cautious']
# ==========
# ['it', 'done', 'way']
# ['thanks', 'sorry', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['i', 'see', 'new']
# ['thanks', 'sorry', 'happy', 'careless', 'cautious']
# ['aggressive', 'cautious', 'defensive']
# ==========
# ['i', 'consume', 'generic']
# ['thanks', 'sorry', 'happy', 'careless', 'calm']
# ['calm']
# ==========
# ['i', 'agree', 'principle']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['aggressive', 'cautious']
# ==========
# ['i', 'use', 'syntax']
# ['thanks', 'sorry', 'careless', 'cautious', 'angry']
# ['cautious']
# ==========
# ['case', 'documented', 'such']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['it', 'remove', 'fine']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['calm', 'cautious']
# ==========
# ['it', 'need', 'best']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious', 'nervous']
# ==========
# ['information', 'be', 'available']
# ['thanks', 'sorry', 'happy', 'calm', 'careless']
# ['calm', 'cautious']
# ==========
# ['it', 'using', 'ability']
# ['sorry', 'thanks', 'cautious', 'careless', 'angry']
# ['cautious', 'nervous']
# ==========
# ['temporary', 'be', 'capitalized']
# ['sorry', 'thanks', 'careless', 'cautious', 'angry']
# ['cautious', 'nervous']
# ==========

# %%
print(count)
# Out:
# 595

# %%
senti[str(['it', 'be', 'right'])]
# Out:
# [[['sorry', 1.6483899570293992],
#   ['thanks', 1.6828200640019426],
#   ['careless', 2.169757363353302],
#   ['cautious', 2.1900414468135905],
#   ['angry', 2.2413094732351273],
#   ['nervous', 2.3126237357018957],
#   ['calm', 2.315673509763462],
#   ['defensive', 2.359600382712654],
#   ['happy', 2.5796628908237995],
#   ['aggressive', 2.6751565596503233]],
#  ['cautious']]

# %%
senti[str(['please', 'use', 'style'])]
# Out:
# [[['sorry', 1.9594776882747365],
#   ['thanks', 1.9977038731142724],
#   ['careless', 2.419342923613293],
#   ['cautious', 2.425931228631142],
#   ['angry', 2.4613654797285567],
#   ['nervous', 2.5294621599877374],
#   ['calm', 2.600191032645513],
#   ['defensive', 2.6246754666069094],
#   ['happy', 2.8218358625061257],
#   ['aggressive', 2.895174899565999]],
#  ['aggressive']]

# %%
senti[str(['i', 'tested', 'code'])]
# Out:
# [[['sorry', 2.0710209168058005],
#   ['thanks', 2.1637030340396355],
#   ['cautious', 2.4623679371951517],
#   ['careless', 2.4727482254693447],
#   ['angry', 2.506288654785309],
#   ['nervous', 2.5582184404080137],
#   ['defensive', 2.6732162254307696],
#   ['calm', 2.712793193903807],
#   ['aggressive', 2.915888105199777],
#   ['happy', 3.004913270082073]],
#  ['calm', 'cautious']]
