# %%
import os
import nltk
import re
from bs4 import BeautifulSoup
from gensim.models.word2vec import Word2Vec
from gensim.models import KeyedVectors
from tinydb import TinyDB
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
github_model = Word2Vec.load('../models/embedding/word2vec_base')
google_model = KeyedVectors.load_word2vec_format('../models/embedding/GoogleNews-vectors-negative300.bin', binary=True)

# %%
google_model.most_similar(positive='sad')
# Out:
# [('saddening', 0.7273085713386536),
#  ('Sad', 0.6610826253890991),
#  ('saddened', 0.6604382395744324),
#  ('heartbreaking', 0.6573508381843567),
#  ('disheartening', 0.6507318019866943),
#  ('Meny_Friedman', 0.648705780506134),
#  ('parishioner_Pat_Patello', 0.6475860476493835),
#  ('saddens_me', 0.6407119035720825),
#  ('distressing', 0.6399092674255371),
#  ('reminders_bobbing', 0.6357713937759399)]

# %%
google_model.most_similar(positive='france')
# Out:
# [('spain', 0.6375303268432617),
#  ('french', 0.6326056718826294),
#  ('germany', 0.6314353942871094),
#  ('europe', 0.6264256238937378),
#  ('italy', 0.625795841217041),
#  ('england', 0.6120775938034058),
#  ('european', 0.6074905395507812),
#  ('belgium', 0.5972346067428589),
#  ('usa', 0.5948355197906494),
#  ('serbia', 0.5805612802505493)]

# %%
google_model.similarity(w1='france', w2='usa')
# Out:
# 0.594835492601592

# %%
google_model.similarity(w1='france', w2='happy')
# Out:
# 0.09177625903757522

# %%
print(github_model.wv.vectors.shape)
print(google_model.vectors.shape)
# Out:
# (38228, 100)
# (3000000, 300)

# %%
print(type(github_model))
print(type(google_model))
# Out:
# <class 'gensim.models.word2vec.Word2Vec'>
# <class 'gensim.models.keyedvectors.Word2VecKeyedVectors'>

# %%
google_model['angry']
# Out:
# array([ 0.22265625,  0.08789062,  0.12597656, -0.10546875, -0.30078125,
#         0.0546875 ,  0.05102539, -0.11474609,  0.15234375,  0.32421875,
#        -0.11230469, -0.17089844, -0.02233887,  0.06445312, -0.10742188,
#        -0.01574707, -0.10302734,  0.17089844,  0.07910156, -0.0534668 ,
#         0.15429688,  0.24414062,  0.38476562,  0.07958984,  0.0378418 ,
#         0.02893066,  0.00909424, -0.07373047,  0.41796875, -0.23535156,
#         0.26367188,  0.06933594, -0.18652344,  0.02001953,  0.26953125,
#        -0.20019531,  0.18652344,  0.04443359, -0.16308594,  0.22753906,
#         0.1328125 , -0.10839844,  0.22851562, -0.27148438, -0.31445312,
#        -0.21582031, -0.34960938, -0.06933594, -0.35546875, -0.01916504,
#        -0.15234375,  0.05126953, -0.14550781,  0.04980469,  0.05371094,
#         0.22460938, -0.08349609, -0.22558594, -0.01416016, -0.12695312,
#        -0.01953125,  0.07714844, -0.265625  ,  0.11621094, -0.21582031,
# ...

# %%
github_model['angry']
# Out:
# /home/jyuwei/.local/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([-0.07348704, -0.01821316,  0.07621907,  0.0172146 ,  0.05419754,
#         0.00531498,  0.17033473, -0.0590469 , -0.0649569 ,  0.00968589,
#        -0.16617033,  0.0533125 ,  0.08919904, -0.12280988, -0.09869587,
#         0.058772  ,  0.09715891,  0.03545953, -0.05727632, -0.1064104 ,
#        -0.10731705, -0.03569974,  0.04887272, -0.01031651, -0.1935924 ,
#        -0.00767451,  0.05443322, -0.07348458,  0.13564873, -0.01562783,
#         0.09384   , -0.01751434,  0.08073365,  0.0958214 ,  0.09788086,
#        -0.16678865,  0.00098048,  0.06596018, -0.05774317, -0.0790081 ,
#        -0.06891327, -0.04498959, -0.002968  ,  0.12816434,  0.00721048,
#         0.07192679,  0.09702388, -0.02827925, -0.01246035,  0.11905541,
# ...

# %%
len(github_model.wv.index2word)
# Out:
# 38228
